# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\dudde\\Downloads\\students_large.csv")

# %%
print(df.head())
# Out:
#    gender  math score  reading score  writing score test preparation course
# 0    male          58             69             43                    none
# 1    male          70             88             42                    none
# 2  female          90             61             31               completed
# 3    male          64             30             81               completed
# 4    male          59             81             57               completed

# %%
sns.set(style="whitegrid")

# %%
sns.countplot(x='gender', data=df)
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
plt.hist(df['math score'])
plt.title("Math Score Distribution")
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.show()

# %%
sns.boxplot(x='gender', y='math score', data=df)
plt.title("Math Score by Gender")
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.title("Correlation Matrix")
plt.show()

# %%
sns.pairplot(df)
plt.show()
